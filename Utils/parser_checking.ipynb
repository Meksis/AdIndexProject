# %%
import parser

# %%
result = parser.parse_some_news(days4parse=7)

# %%
result.date
# Out:
# 0     2023-12-08
# 1     2023-12-08
# 2     2023-12-08
# 3     2023-12-08
# 4     2023-12-08
#          ...
# 141   2023-11-29
# 142   2023-11-29
# 143   2023-11-29
# 144   2023-11-29
# 145   2023-11-29
# Name: date, Length: 146, dtype: datetime64[ns]

# %%
result
# Out:
#           date                          author  visitors   post_tag post_id  \
# 0   2023-12-08         Петрова Мария Сергеевна      5486  Тенденции  317833
# 1   2023-12-08          Жукова Ирина Ильинична      6935  Тенденции  317832
# 2   2023-12-08  Григорьева Людмила Григорьевна     11666   Эккаунты  317827
# 3   2023-12-08    Данилова Светлана Викторовна     13749    Креатив  317825
# 4   2023-12-08    Данилова Светлана Викторовна     15342      Медиа  317821
# ..         ...                             ...       ...        ...     ...
# 141 2023-11-29          Жукова Ирина Ильинична      1498      Право  317525
# 142 2023-11-29      Сидоров Антон Владимирович     10690  Маркетинг  317523
# 143 2023-11-29        Борисова Ольга Борисовна      5612  Тенденции  317521
# 144 2023-11-29      Сидоров Антон Владимирович     18560    Digital  317520
# 145 2023-11-29       Егорова Надежда Андреевна     12641      Право  317519
#
# ...
