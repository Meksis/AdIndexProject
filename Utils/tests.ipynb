# %%
import datetime
import parser
import pandas as pd

# %%
df = parser.parse_some_news(datetime.date(2023, 12, 14), datetime.date.today())

# %%
df
# Out:
#                    date                          author      post_tag  \
# 0   2023-12-18 19:03:00            Иванов Иван Иванович      Эккаунты
# 1   2023-12-18 18:51:00         Петрова Мария Сергеевна     Тенденции
# 2   2023-12-18 18:48:00        Борисова Ольга Борисовна     Маркетинг
# 3   2023-12-18 18:31:00          Жукова Ирина Ильинична        Дизайн
# 4   2023-12-18 17:51:00            Иванов Иван Иванович       Креатив
# 5   2023-12-18 16:58:00        Борисова Ольга Борисовна         Медиа
# 6   2023-12-18 14:32:00       Егорова Надежда Андреевна       Digital
# 7   2023-12-18 13:51:00            Иванов Иван Иванович         Право
# 8   2023-12-18 13:03:00         Петрова Мария Сергеевна  Пресс-релизы
# 9   2023-12-18 12:53:00            Иванов Иван Иванович  Исследования
# 10  2023-12-18 12:35:00        Борисова Ольга Борисовна  Исследования
# 11  2023-12-18 11:18:00       Егорова Надежда Андреевна         Медиа
# ...

# %%
df_extend = pd.DataFrame()

for row in df.iloc:
    # print(row)
    url = row.link
    words = ['daysAgo', 'yesterday', 'today']
    word_from = ''
    word_to = ''

    days_delta = (pd.Timestamp(datetime.date.today()).date() - pd.Timestamp(row.date).date()).days
    
    match days_delta:
        case 0:
            word_from = words[2]
        
        case 1:
            word_from = words[1]
        
        case _:
            word_from = f'{days_delta}{words[0]}'
        
    print(word_from)



print(df_extend)
# Out:
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# today
# 2daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 3daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# 4daysAgo
# Empty DataFrame
# Columns: []
# Index: []
