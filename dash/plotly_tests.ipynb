# %%
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv('AdIndex main news METRICS 2023-12-14.csv', index_col=0, parse_dates=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df = pd.read_csv('AdIndex main news METRICS 2023-12-14.csv', index_col=0, parse_dates=True)
#
# File c:\Python310\lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
df
# Out:
#          date                          author            post_tag  post_id  \
# 0  2023-12-13         Петрова Мария Сергеевна           Тенденции   318261
# 1  2023-12-13        Борисова Ольга Борисовна             Креатив   318259
# 2  2023-12-13  Григорьева Людмила Григорьевна           Тенденции   318152
# 3  2023-12-13            Иванов Иван Иванович               Кадры   318116
# 4  2023-12-13       Егорова Надежда Андреевна  Социальные проекты   318115
# ..        ...                             ...                 ...      ...
# 94 2023-12-04        Борисова Ольга Борисовна             Digital   317666
# 95 2023-12-04    Данилова Светлана Викторовна           Маркетинг   317663
# 96 2023-12-04          Жукова Ирина Ильинична               Право   317662
# 97 2023-12-04          Жукова Ирина Ильинична           Тенденции   317657
# 98 2023-12-04    Андреева Анастасия Андреевна           Маркетинг   317656
#
# ...

# %%
df['date'] = df['date'].apply(lambda x: pd.to_datetime(x))

# %%
df
# Out:
#          date                          author            post_tag  post_id  \
# 0  2023-12-13         Петрова Мария Сергеевна           Тенденции   318261
# 1  2023-12-13        Борисова Ольга Борисовна             Креатив   318259
# 2  2023-12-13  Григорьева Людмила Григорьевна           Тенденции   318152
# 3  2023-12-13            Иванов Иван Иванович               Кадры   318116
# 4  2023-12-13       Егорова Надежда Андреевна  Социальные проекты   318115
# ..        ...                             ...                 ...      ...
# 94 2023-12-04        Борисова Ольга Борисовна             Digital   317666
# 95 2023-12-04    Данилова Светлана Викторовна           Маркетинг   317663
# 96 2023-12-04          Жукова Ирина Ильинична               Право   317662
# 97 2023-12-04          Жукова Ирина Ильинична           Тенденции   317657
# 98 2023-12-04    Андреева Анастасия Андреевна           Маркетинг   317656
#
# ...

# %%
px.line(df['post_id'])

# %% [markdown]
# ---

# %%
# {'id': 'Model', 'name': 'Model'}


[{ 'id' : column, 'name' : column } for column in df.columns]
# Out:
# [{'id': 'date', 'name': 'date'},
#  {'id': 'author', 'name': 'author'},
#  {'id': 'post_tag', 'name': 'post_tag'},
#  {'id': 'post_id', 'name': 'post_id'},
#  {'id': 'link', 'name': 'link'},
#  {'id': 'Посетители', 'name': 'Посетители'},
#  {'id': 'Читатели', 'name': 'Читатели'},
#  {'id': 'Уникальные пользователи', 'name': 'Уникальные пользователи'},
#  {'id': '% недочитываемости', 'name': '% недочитываемости'},
#  {'id': 'Глубина просмотра', 'name': 'Глубина просмотра'},
#  {'id': 'Ср. время на сайте (сек)', 'name': 'Ср. время на сайте (сек)'},
#  {'id': '0', 'name': '0'}]

# %%
for row in df.to_dict('records'):
    print(row)

    row.update({'editable' : True if row})
# Out:
# {'date': Timestamp('2023-12-13 00:00:00'), 'author': 'Петрова Мария Сергеевна', 'post_tag': 'Тенденции', 'post_id': 318261, 'link': 'https://adindex.ru/news/tendencies/2023/12/13/318261.phtml', 'Посетители': 5.0, 'Читатели': 30.0, 'Уникальные пользователи': 5.0, '% недочитываемости': 0.0, 'Глубина просмотра': 2.0, 'Ср. время на сайте (сек)': 16.5, '0': nan}
# {'date': Timestamp('2023-12-13 00:00:00'), 'author': 'Борисова Ольга Борисовна', 'post_tag': 'Креатив', 'post_id': 318259, 'link': 'https://adindex.ru/news/creative/2023/12/13/318259.phtml', 'Посетители': 14.0, 'Читатели': 71.0, 'Уникальные пользователи': 14.0, '% недочитываемости': 0.0, 'Глубина просмотра': 3.5, 'Ср. время на сайте (сек)': 79.214285715, '0': nan}
# ...
