# %%
import pandas as pd

# %%
df = pd.read_csv('dash\csvs\AdIndex main news METRICS 2023-12-14.csv')
df.head()
# Out:
#    Unnamed: 0        date                          author            post_tag  \
# 0           0  2023-12-13         Петрова Мария Сергеевна           Тенденции
# 1           1  2023-12-13        Борисова Ольга Борисовна             Креатив
# 2           2  2023-12-13  Григорьева Людмила Григорьевна           Тенденции
# 3           3  2023-12-13            Иванов Иван Иванович               Кадры
# 4           4  2023-12-13       Егорова Надежда Андреевна  Социальные проекты
#
#    post_id                                               link  Посетители  \
# 0   318261  https://adindex.ru/news/tendencies/2023/12/13/...         5.0
# 1   318259  https://adindex.ru/news/creative/2023/12/13/31...        14.0
# 2   318152  https://adindex.ru/news/tendencies/2023/12/13/...        17.0
# 3   318116  https://adindex.ru/news/hr/2023/12/13/318116.p...         9.0
# 4   318115  https://adindex.ru/news/social_advertising/202...         5.0
#
# ...

# %%
cl_df = df[['link','author','Читатели','Глубина просмотра']]

# %%
cl_df['трафик с ТГ']= 0
cl_df['трафик с ВК']= 0
cl_df['трафик с home']= 0
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_20432\2041541511.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_df['трафик с ТГ']= 0
# C:\Users\danie\AppData\Local\Temp\ipykernel_20432\2041541511.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cl_df['трафик с ВК']= 0
# C:\Users\danie\AppData\Local\Temp\ipykernel_20432\2041541511.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
cl_df
# Out:
#                                                  link  \
# 0   https://adindex.ru/news/tendencies/2023/12/13/...
# 1   https://adindex.ru/news/creative/2023/12/13/31...
# 2   https://adindex.ru/news/tendencies/2023/12/13/...
# 3   https://adindex.ru/news/hr/2023/12/13/318116.p...
# 4   https://adindex.ru/news/social_advertising/202...
# ..                                                ...
# 94  https://adindex.ru/news/digital/2023/12/4/3176...
# 95  https://adindex.ru/news/marketing/2023/12/4/31...
# 96  https://adindex.ru/news/right/2023/12/4/317662...
# 97  https://adindex.ru/news/tendencies/2023/12/4/3...
# 98  https://adindex.ru/news/marketing/2023/12/4/31...
#
#                             author  Читатели  Глубина просмотра  трафик с ТГ  \
# 0          Петрова Мария Сергеевна      30.0               2.00            0
# 1         Борисова Ольга Борисовна      71.0               3.50            0
# 2   Григорьева Людмила Григорьевна      46.0               1.25            0
# ...
